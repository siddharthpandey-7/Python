# %% [markdown]
# Comparing Strings

# %%
string1 = "apple"
string2 = "banana"

print(string1 == string2) ## Equal to
print(string1 != string2) ## Not equal to
print(string1 < string2) ## Less than
print(string1 > string2) ## Greater than
print(string1 <= string2) ## Less than or equal to
print(string1 >= string2) ## Greater than or equal to
# Out:
# False
# True
# True
# False
# True
# False

# %%
ord('a')
# Out:
# 97

# %%
ord('b')
# Out:
# 98

# %%
"cat" < "catalog"
# Out:
# True

# %%
ord('Z')
# Out:
# 90

# %%
"Zebra" < "apple"
# Out:
# True

# %% [markdown]
# replace()

# %%
original_string = "Hello, world!"

## Replace "world" with "Python"
new_string = original_string.replace("world", "Python")
print(new_string)
# Out:
# Hello, Python!

# %% [markdown]
# split()

# %%
sentence = "This is a very interesting session"
words = sentence.split()
print(words)
# Out:
# ['This', 'is', 'a', 'very', 'interesting', 'session']

# %%
names = "Rohit, Virat, Dhoni, Axar, Samson, Ishant, Jadeja"
names_list = names.split(',')
print(names_list)
# Out:
# ['Rohit', ' Virat', ' Dhoni', ' Axar', ' Samson', ' Ishant', ' Jadeja']

# %%
string = "Hello-World"
print(string.split("-"))
# Out:
# ['Hello', 'World']

# %%
string = "HelloWorld"
print(string.split("-"))
# Out:
# ['HelloWorld']

# %% [markdown]
# Formatting

# %%
age = 20
text = "My name is Siddharth, I am " + age
print(text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 age = 30
# ----> 2 text = "My name is Siddharth, I am " + age
#       3 print(text)
#
# TypeError: can only concatenate str (not "int") to str

# %%
age = 20
text = f"My name is Siddharth, I am {age} years old"
print(text)
# Out:
# My name is Siddharth, I am 20 years old

# %% [markdown]
# strip() - removes any whitespace from the beginning or the end.

# %%
text = "      Hello, Python Developers!    "
stripped_text = text.strip()
print(stripped_text)
# Out:
# Hello, Python Developers!

# %%
print(text)
# Out:
#       Hello, Python Developers!

# %%
text = "      Hello, Python        Developers!    "
stripped_text = text.strip()
print(stripped_text)
# Out:
# Hello, Python        Developers!

# %% [markdown]
# index() - returns ValueError if the substring is not present in the main string

# %%
string = "Hello, World!"
index = string.index("World")
print(index)
# Out:
# 7

# %%
index = string.index("Python")
print(index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 index = string.index("Python")
#       2 print(index)
#
# ValueError: substring not found

# %% [markdown]
# find() - returns -1 if the substring is not present in the main string

# %%
string = "Hello, World!"
index = string.find("World")
print(index)
# Out:
# 7

# %%
index = string.find("Python")
print(index)
# Out:
# -1

# %%
sentence = "This is a sample sentence"
count = sentence.count("is")
print(count)
# Out:
# 2

# %%
text1 = "Hello"
text2 = "Hello123"
print(text1. isalpha())
# Out:
# True

# %%
print(text2.isalpha())
# Out:
# False

# %%
sentence = "This is a sample sentence"
count = sentence.count("a")
print(count)
# Out:
# 2

# %% [markdown]
# isupper()
#
# islower()
#
# isdigit()

# %%
text1 = "HELLO"
text1.isupper()
# Out:
# True

# %%
text1.islower()
# Out:
# False

# %%
text1.isdigit()
# Out:
# False

# %%
text = "Hello World! 1234"
swapped_text = text.swapcase()
print(swapped_text)
# Out:
# hELLO wORLD! 1234
